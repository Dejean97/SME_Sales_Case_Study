# %%
import pandas as pd
import numpy as np
import datetime as dt

pd.set_option('display.max_columns', None)

# %%
###Read in worksheets

xls = pd.ExcelFile('raw_data_for_cleaning.xlsx')
transac = pd.read_excel(xls, 'Transactions')
custdemo = pd.read_excel(xls, 'CustomerDemographic')
custadd = pd.read_excel(xls, 'CustomerAddress')

# %%
transac.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# 3     1198.46         381.10                  36145.0
# 4     1765.30         709.48                  42226.0

# %%
transac.shape
# Out:
# (20000, 13)

# %%
transac.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
###Identify records with null values
transac.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
###Identify proportion of records with null values
percent_missing = transac.isnull().sum() * 100 / len(transac)
missing_value_transac = pd.DataFrame({'percent_missing': percent_missing})
missing_value_transac.sort_values('percent_missing', ascending=False, inplace=True)
missing_value_transac
# Out:
#                          percent_missing
# online_order                       1.800
# brand                              0.985
# product_line                       0.985
# product_class                      0.985
# product_size                       0.985
# standard_cost                      0.985
# product_first_sold_date            0.985
# transaction_id                     0.000
# product_id                         0.000
# customer_id                        0.000
# transaction_date                   0.000
# order_status                       0.000
# list_price                         0.000

# %%
transac['transaction_id'].nunique()
# Out:
# 20000

# %%
transac['customer_id'].nunique()
# Out:
# 3494

# %%
###List values and counts per column
for c in transac.columns:
    print ("---- %s ---" % c)
    print (transac[c].value_counts())
# Out:
# ---- transaction_id ---
# 2049     1
# 17714    1
# 15677    1
# 13628    1
# 3387     1
#         ..
# 4759     1
# 6806     1
# 661      1
# 2708     1
# 2047     1
# Name: transaction_id, Length: 20000, dtype: int64
# ---- product_id ---
# 0      1378
# 3       354
# 1       311
# 35      268
# 38      267
#        ...
# 71      137
# 16      136
# 8       136
# 100     130
# 47      121
# Name: product_id, Length: 101, dtype: int64
# ---- customer_id ---
# 1068    14
# 2476    14
# 2183    14
# 2548    13
# 3232    13
#         ..
# 2876     1
# 822      1
# 2477     1
# 1846     1
# 1544     1
# Name: customer_id, Length: 3494, dtype: int64
# ---- transaction_date ---
# 2017-08-18    82
# 2017-02-14    82
# 2017-10-15    76
# 2017-01-31    73
# 2017-12-19    71
#               ..
# 2017-01-12    38
# 2017-12-07    37
# 2017-03-29    36
# 2017-09-25    35
# 2017-10-19    32
# Name: transaction_date, Length: 364, dtype: int64
# ---- online_order ---
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64
# ---- order_status ---
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64
# ---- brand ---
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64
# ---- product_line ---
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64
# ---- product_class ---
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64
# ---- product_size ---
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64
# ---- list_price ---
# 2091.47    465
# 1403.50    396
# 71.49      274
# 1231.15    235
# 1890.39    233
#           ...
# 1656.86      1
# 1413.98      1
# 1624.69      1
# 1678.71      1
# 1392.76      1
# Name: list_price, Length: 296, dtype: int64
# ---- standard_cost ---
# 388.920000    465
# 954.820000    396
# 53.620000     274
# 161.600000    235
# 260.140000    233
#              ...
# 151.960000    124
# 206.350000    114
# 667.400024      1
# 270.299988      1
# 312.735016      1
# Name: standard_cost, Length: 103, dtype: int64
# ---- product_first_sold_date ---
# 33879.0    234
# 41064.0    229
# 37823.0    227
# 39880.0    222
# 38216.0    220
#           ...
# 41848.0    169
# 42404.0    168
# 41922.0    166
# 37659.0    163
# 34586.0    162
# Name: product_first_sold_date, Length: 100, dtype: int64

# %%
###Drop NAs and Nulls
clean_transac = transac.dropna(how='any',axis=0)

# %%
clean_transac.shape
# Out:
# (19445, 13)

# %%
clean_transac.isnull().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
clean_transac.dtypes
# Out:
# transaction_id                      int64
# product_id                          int64
# customer_id                         int64
# transaction_date           datetime64[ns]
# online_order                      float64
# order_status                       object
# brand                              object
# product_line                       object
# product_class                      object
# product_size                       object
# list_price                        float64
# standard_cost                     float64
# product_first_sold_date           float64
# dtype: object

# %%
###Convert product_first_sold_date to date format
clean_transac['new_product_first_sold_date'] = pd.to_timedelta(clean_transac.product_first_sold_date, unit='D') + pd.to_datetime('1899-12-30')
# Out:
# <ipython-input-77-65dacac34c48>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_transac['new_product_first_sold_date'] = pd.to_timedelta(clean_transac.product_first_sold_date, unit='D') + pd.to_datetime('1899-12-30')

# %%
###Drop old date column
clean_transac = clean_transac.drop('product_first_sold_date', 1)

# %%
clean_transac.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost new_product_first_sold_date
# 0       71.49          53.62                  2012-12-02
# 1     2091.47         388.92                  2014-03-03
# 2     1793.43         248.82                  1999-07-20
# 3     1198.46         381.10                  1998-12-16
# 4     1765.30         709.48                  2015-08-10

# %%
clean_transac.transaction_date.max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
custdemo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# 2              Property      Mass Customer                  N
# 3                    IT      Mass Customer                  N
# 4                   NaN  Affluent Customer                  N
#
#                                              default owns_car  tenure
# 0                                                 "'      Yes    11.0
# 1                       <script>alert('hi')</script>      Yes    16.0
# 2                                2018-02-01 00:00:00      Yes    15.0
# 3  () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                NIL      Yes     8.0

# %%
custdemo.shape
# Out:
# (4000, 13)

# %%
custdemo['customer_id'].nunique()
# Out:
# 4000

# %%
custdemo.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
###Identify records with null values
custdemo.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
for c in custdemo.columns:
    print ("---- %s ---" % c)
    print (custdemo[c].value_counts())
# Out:
# ---- customer_id ---
# 2049    1
# 3391    1
# 1318    1
# 3367    1
# 1322    1
#        ..
# 677     1
# 2728    1
# 681     1
# 2732    1
# 2047    1
# Name: customer_id, Length: 4000, dtype: int64
# ---- first_name ---
# Timmie      5
# Max         5
# Tobe        5
# Kippy       4
# Kim         4
#            ..
# Domeniga    1
# Teriann     1
# Belia       1
# Mata        1
# Antonino    1
# Name: first_name, Length: 3139, dtype: int64
# ---- last_name ---
# Ramsdell     3
# Pristnor     3
# Lithgow      2
# Struys       2
# Mungham      2
#             ..
# Wallis       1
# Scedall      1
# Waleran      1
# Braundt      1
# Kitchener    1
# Name: last_name, Length: 3725, dtype: int64
# ---- gender ---
# Female    2037
# Male      1872
# U           88
# M            1
# F            1
# Femal        1
# Name: gender, dtype: int64
# ---- past_3_years_bike_related_purchases ---
# 19    56
# 16    56
# 67    54
# 20    54
# 2     50
#       ..
# 8     28
# 85    27
# 86    27
# 95    27
# 92    24
# Name: past_3_years_bike_related_purchases, Length: 100, dtype: int64
# ---- DOB ---
# 1978-01-30    7
# 1978-08-19    4
# 1964-07-08    4
# 1976-09-25    4
# 1976-07-16    4
#              ..
# 2001-01-22    1
# 1955-03-06    1
# 1966-08-05    1
# 1968-11-16    1
# 1958-08-02    1
# Name: DOB, Length: 3448, dtype: int64
# ---- job_title ---
# Business Systems Development Analyst    45
# Tax Accountant                          44
# Social Worker                           44
# Internal Auditor                        42
# Recruiting Manager                      41
#                                         ..
# Account Representative II                4
# Research Assistant III                   3
# Health Coach III                         3
# Health Coach I                           3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64
# ---- job_industry_category ---
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64
# ---- wealth_segment ---
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segment, dtype: int64
# ---- deceased_indicator ---
# N    3998
# Y       2
# Name: deceased_indicator, dtype: int64
# ---- default ---
# 100                                       113
# 1                                         112
# -1                                        111
# -100                                       99
# â°â´âµâââ                                  53
#                                          ...
# '"''''"                                    31
# /dev/null; touch /tmp/blns.fail ; echo     30
# âªâªtestâª                                 29
# ì¸ëë°í ë¥´                                 27
# ,ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ           25
# Name: default, Length: 90, dtype: int64
# ---- owns_car ---
# Yes    2024
# No     1976
# Name: owns_car, dtype: int64
# ---- tenure ---
# 7.0     235
# 5.0     228
# 11.0    221
# 10.0    218
# 16.0    215
# 8.0     211
# 18.0    208
# 12.0    202
# 14.0    200
# 9.0     200
# 6.0     192
# 4.0     191
# 13.0    191
# 17.0    182
# 15.0    179
# 1.0     166
# 3.0     160
# 19.0    159
# 2.0     150
# 20.0     96
# 22.0     55
# 21.0     54
# Name: tenure, dtype: int64

# %%
###Identify proportion of records with null values
percent_missing = custdemo.isnull().sum() * 100 / len(custdemo)
missing_value_custdemo = pd.DataFrame({'percent_missing': percent_missing})
missing_value_custdemo.sort_values('percent_missing', ascending=False, inplace=True)
missing_value_custdemo
# Out:
#                                      percent_missing
# job_industry_category                         16.400
# job_title                                     12.650
# default                                        7.550
# last_name                                      3.125
# DOB                                            2.175
# tenure                                         2.175
# customer_id                                    0.000
# first_name                                     0.000
# gender                                         0.000
# past_3_years_bike_related_purchases            0.000
# wealth_segment                                 0.000
# deceased_indicator                             0.000
# owns_car                                       0.000

# %%
###Drop NAs and Nulls
clean_custdemo = custdemo.dropna(how='any',axis=0)
###Drop 'default' column
clean_custdemo = clean_custdemo.drop('default', 1)
clean_custdemo.shape
# Out:
# (2630, 12)

# %%
clean_custdemo.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp       F
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure
# 0      Mass Customer                  N      Yes    11.0
# 1      Mass Customer                  N      Yes    16.0
# 2      Mass Customer                  N      Yes    15.0
# 8  Affluent Customer                  N      Yes     8.0
# 9      Mass Customer                  N      Yes    20.0

# %%
###Convert 'gender' values to uniform format
clean_custdemo['gender'] = clean_custdemo['gender'].replace('Femal' ,'Female')

# %%
clean_custdemo['gender'] = clean_custdemo['gender'].replace('F' ,'Female')

# %%
clean_custdemo['gender'].value_counts()
# Out:
# Female    1368
# Male      1262
# Name: gender, dtype: int64

# %%
latest_transaction = dt.datetime(2017,12,30)

# %%
###Create customer age column
clean_custdemo['age'] = latest_transaction - clean_custdemo.DOB

clean_custdemo['age'] = clean_custdemo.age / np.timedelta64(1, 'Y')

clean_custdemo['age'] = clean_custdemo['age'].astype(np.int64)

clean_custdemo.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure  age
# 0      Mass Customer                  N      Yes    11.0   64
# 1      Mass Customer                  N      Yes    16.0   37
# 2      Mass Customer                  N      Yes    15.0   63
# 8  Affluent Customer                  N      Yes     8.0   44
# 9      Mass Customer                  N      Yes    20.0   29

# %%
for c in clean_custdemo.columns:
    print ("---- %s ---" % c)
    print (clean_custdemo[c].value_counts())
# Out:
# ---- customer_id ---
# 2049    1
# 2686    1
# 2688    1
# 641     1
# 2690    1
#        ..
# 3393    1
# 1346    1
# 1350    1
# 3399    1
# 2047    1
# Name: customer_id, Length: 2630, dtype: int64
# ---- first_name ---
# Tobe        5
# Gerome      4
# Osgood      4
# Lindsay     4
# Adrianne    3
#            ..
# Eli         1
# Farrel      1
# Jammal      1
# Maren       1
# Hayden      1
# Name: first_name, Length: 2234, dtype: int64
# ---- last_name ---
# Pristnor       2
# Antognazzi     2
# Dwerryhouse    2
# Pountain       2
# Zisneros       2
#               ..
# Odlin          1
# Jerche         1
# Brown          1
# McIlhone       1
# Orehead        1
# Name: last_name, Length: 2560, dtype: int64
# ---- gender ---
# Female    1368
# Male      1262
# Name: gender, dtype: int64
# ---- past_3_years_bike_related_purchases ---
# 2     39
# 73    39
# 38    37
# 48    34
# 97    34
#       ..
# 8     19
# 1     18
# 21    18
# 58    15
# 92    14
# Name: past_3_years_bike_related_purchases, Length: 100, dtype: int64
# ---- DOB ---
# 1978-01-30    6
# 1976-07-16    4
# 1999-07-28    3
# 1988-11-27    3
# 1987-06-16    3
#              ..
# 1999-05-10    1
# 1980-06-21    1
# 1954-09-04    1
# 1989-08-09    1
# 1973-07-20    1
# Name: DOB, Length: 2413, dtype: int64
# ---- job_title ---
# Social Worker                   38
# Sales Representative            36
# Dental Hygienist                34
# Chemical Engineer               34
# Desktop Support Technician      33
#                                 ..
# Human Resources Assistant IV     2
# Accounting Assistant IV          2
# Research Assistant III           2
# Database Administrator II        1
# Developer I                      1
# Name: job_title, Length: 195, dtype: int64
# ---- job_industry_category ---
# Manufacturing         635
# Financial Services    626
# Health                496
# Retail                278
# Property              222
# IT                    119
# Entertainment         110
# Argiculture            91
# Telecommunications     53
# Name: job_industry_category, dtype: int64
# ---- wealth_segment ---
# Mass Customer        1300
# High Net Worth        674
# Affluent Customer     656
# Name: wealth_segment, dtype: int64
# ---- deceased_indicator ---
# N    2628
# Y       2
# Name: deceased_indicator, dtype: int64
# ---- owns_car ---
# Yes    1361
# No     1269
# Name: owns_car, dtype: int64
# ---- tenure ---
# 7.0     157
# 5.0     155
# 12.0    154
# 16.0    148
# 8.0     147
# 10.0    143
# 9.0     141
# 18.0    140
# 11.0    137
# 6.0     135
# 14.0    130
# 4.0     122
# 13.0    122
# 17.0    116
# 3.0     111
# 19.0    110
# 15.0    107
# 1.0     106
# 2.0     102
# 20.0     67
# 22.0     40
# 21.0     40
# Name: tenure, dtype: int64
# ---- age ---
# 39    153
# 40    133
# 43    111
# 41    105
# 42     84
# 38     84
# 44     81
# 31     79
# 37     78
# 58     62
# 32     60
# 53     59
# 48     56
# 23     56
# 25     55
# 19     55
# 36     55
# 29     54
# 22     54
# 46     53
# 28     52
# 30     52
# 52     51
# 50     50
# 20     50
# 49     50
# 55     47
# 18     44
# 61     43
# 24     41
# 51     40
# 60     40
# 27     40
# 54     39
# 21     38
# 45     37
# 47     37
# 63     36
# 57     36
# 62     36
# 56     36
# 59     32
# 26     30
# 34     29
# 17     26
# 16     25
# 35     23
# 33     21
# 64     16
# 15      2
# 86      1
# 82      1
# 74      1
# 73      1
# Name: age, dtype: int64

# %%
custadd.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
custadd.shape
# Out:
# (3999, 6)

# %%
custadd.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
###Identify records with null values


custadd.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
custadd['customer_id'].nunique()
# Out:
# 3999

# %%
for c in custadd.columns:
    print ("---- %s ---" % c)
    print (custadd[c].value_counts())
# Out:
# ---- customer_id ---
# 2049    1
# 1346    1
# 3367    1
# 1322    1
# 3371    1
#        ..
# 2724    1
# 677     1
# 2728    1
# 681     1
# 2047    1
# Name: customer_id, Length: 3999, dtype: int64
# ---- address ---
# 3 Talisman Place           2
# 3 Mariners Cove Terrace    2
# 64 Macpherson Junction     2
# 60447 Ridgeway Plaza       1
# 25 Graceland Way           1
#                           ..
# 572 Spohn Drive            1
# 08180 Golf Park            1
# 95294 Karstens Park        1
# 7380 Canary Pass           1
# 1 Namekagon Parkway        1
# Name: address, Length: 3996, dtype: int64
# ---- postcode ---
# 2170    31
# 2145    30
# 2155    30
# 2153    29
# 3977    26
#         ..
# 3331     1
# 3036     1
# 3321     1
# 3305     1
# 2143     1
# Name: postcode, Length: 873, dtype: int64
# ---- state ---
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64
# ---- country ---
# Australia    3999
# Name: country, dtype: int64
# ---- property_valuation ---
# 9     647
# 8     646
# 10    577
# 7     493
# 11    281
# 6     238
# 5     225
# 4     214
# 12    195
# 3     186
# 1     154
# 2     143
# Name: property_valuation, dtype: int64

# %%
clean_custadd = custadd
clean_custadd.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
###Convert 'gender' values to uniform format
clean_custadd['state'] = clean_custadd['state'].replace('Victoria' ,'VIC')

# %%
clean_custadd['state'] = clean_custadd['state'].replace('New South Wales' ,'NSW')

# %%
clean_custadd['state'].value_counts()
# Out:
# NSW    2140
# VIC    1021
# QLD     838
# Name: state, dtype: int64

# %%
###Merge tables on customer ID, only retaining data where customer are present in each table (inner join)
cust_list = pd.merge(clean_custdemo,
                     clean_custadd,
                      on ='customer_id', 
                      how ='inner')
cust_list
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               2        Eli    Bockman    Male
# 2               9       Mala       Lind  Female
# 3              12    Sawyere   Flattman    Male
# 4              13   Gabriele   Norcross    Male
# ...           ...        ...        ...     ...
# 2623         3993       Andi    Dumelow  Female
# 2624         3994    Stephie      Byars  Female
# 2625         3995      Rusty     Iapico    Male
# 2626         3996    Rosalia   Halgarth  Female
# 2627         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      97 1973-03-10
# 3                                      58 1994-07-21
# 4                                      38 1955-02-15
# ...                                   ...        ...
# 2623                                    6 1974-12-05
# 2624                                    5 1989-04-07
# 2625                                   93 1975-12-12
# 2626                                    8 1975-08-09
# 2627                                   87 2001-07-13
#
#                                  job_title job_industry_category  \
# 0                      Executive Secretary                Health
# 1                   Administrative Officer    Financial Services
# 2     Business Systems Development Analyst           Argiculture
# 3                   Nuclear Power Engineer         Manufacturing
# 4                              Developer I    Financial Services
# ...                                    ...                   ...
# 2623                             Librarian         Entertainment
# 2624          Structural Analysis Engineer         Manufacturing
# 2625                       Staff Scientist         Manufacturing
# 2626                 VP Product Management                Health
# 2627                       Statistician II         Manufacturing
#
#          wealth_segment deceased_indicator owns_car  tenure  age  \
# 0         Mass Customer                  N      Yes    11.0   64
# 1         Mass Customer                  N      Yes    16.0   37
# 2     Affluent Customer                  N      Yes     8.0   44
# 3         Mass Customer                  N       No     8.0   23
# 4        High Net Worth                  N      Yes     8.0   62
# ...                 ...                ...      ...     ...  ...
# 2623      Mass Customer                  N       No    10.0   43
# 2624  Affluent Customer                  N       No    12.0   28
# 2625      Mass Customer                  N      Yes    14.0   42
# 2626      Mass Customer                  N       No    19.0   42
# 2627     High Net Worth                  N      Yes     1.0   16
#
#                       address  postcode state    country  property_valuation
# 0          060 Morning Avenue      2016   NSW  Australia                  10
# 1         6 Meadow Vale Court      2153   NSW  Australia                  10
# 2             97736 7th Trail      2023   NSW  Australia                  12
# 3     44339 Golden Leaf Alley      4557   QLD  Australia                   4
# 4         2 Sutherland Street      3799   VIC  Australia                   6
# ...                       ...       ...   ...        ...                 ...
# 2623        681 Elmside Place      3750   VIC  Australia                   6
# 2624   2918 Summer Ridge Hill      3030   VIC  Australia                   2
# 2625            613 Erie Lane      2088   NSW  Australia                  12
# 2626       0 Transport Center      3977   VIC  Australia                   6
# 2627      4 Dovetail Crossing      2350   NSW  Australia                   2
#
# [2628 rows x 18 columns]

# %%
###Join transactions to joined demographic and address data
###Definitive Cust List
cust_list = pd.merge(cust_list,
                     clean_transac,
                      on ='customer_id', 
                      how ='inner')
cust_list
# Out:
#        customer_id first_name  last_name  gender  \
# 0                1    Laraine  Medendorp  Female
# 1                1    Laraine  Medendorp  Female
# 2                1    Laraine  Medendorp  Female
# 3                1    Laraine  Medendorp  Female
# 4                1    Laraine  Medendorp  Female
# ...            ...        ...        ...     ...
# 12965         3496      Danya   Burnyeat    Male
# 12966         3496      Danya   Burnyeat    Male
# 12967         3497       Thia      O'Day  Female
# 12968         3497       Thia      O'Day  Female
# 12969         3497       Thia      O'Day  Female
#
#        past_3_years_bike_related_purchases        DOB  \
# 0                                       93 1953-10-12
# 1                                       93 1953-10-12
# 2                                       93 1953-10-12
# 3                                       93 1953-10-12
# 4                                       93 1953-10-12
# ...                                    ...        ...
# 12965                                   99 1986-04-25
# 12966                                   99 1986-04-25
# 12967                                   73 1986-05-03
# 12968                                   73 1986-05-03
# 12969                                   73 1986-05-03
#
#                          job_title job_industry_category     wealth_segment  \
# 0              Executive Secretary                Health      Mass Customer
# 1              Executive Secretary                Health      Mass Customer
# 2              Executive Secretary                Health      Mass Customer
# 3              Executive Secretary                Health      Mass Customer
# 4              Executive Secretary                Health      Mass Customer
# ...                            ...                   ...                ...
# 12965                       Editor         Manufacturing      Mass Customer
# 12966                       Editor         Manufacturing      Mass Customer
# 12967  Administrative Assistant IV         Manufacturing  Affluent Customer
# 12968  Administrative Assistant IV         Manufacturing  Affluent Customer
# 12969  Administrative Assistant IV         Manufacturing  Affluent Customer
#
#       deceased_indicator owns_car  tenure  age              address  postcode  \
# 0                      N      Yes    11.0   64   060 Morning Avenue      2016
# 1                      N      Yes    11.0   64   060 Morning Avenue      2016
# 2                      N      Yes    11.0   64   060 Morning Avenue      2016
# 3                      N      Yes    11.0   64   060 Morning Avenue      2016
# 4                      N      Yes    11.0   64   060 Morning Avenue      2016
# ...                  ...      ...     ...  ...                  ...       ...
# 12965                  N      Yes    19.0   31  2565 Caliangt Point      2171
# 12966                  N      Yes    19.0   31  2565 Caliangt Point      2171
# 12967                  N      Yes    18.0   31  96 Delladonna Trail      3976
# 12968                  N      Yes    18.0   31  96 Delladonna Trail      3976
# 12969                  N      Yes    18.0   31  96 Delladonna Trail      3976
#
#       state    country  property_valuation  transaction_id  product_id  \
# 0       NSW  Australia                  10              94          86
# 1       NSW  Australia                  10            3765          38
# 2       NSW  Australia                  10            5157          47
# 3       NSW  Australia                  10            9785          72
# 4       NSW  Australia                  10           13424           2
# ...     ...        ...                 ...             ...         ...
# 12965   NSW  Australia                   9            9769           5
# 12966   NSW  Australia                   9           18797          16
# 12967   VIC  Australia                   5            6926           1
# 12968   VIC  Australia                   5            8276          18
# 12969   VIC  Australia                   5           10493          78
#
#       transaction_date  online_order order_status           brand  \
# 0           2017-12-23           0.0     Approved      OHM Cycles
# 1           2017-04-06           1.0     Approved           Solex
# 2           2017-05-11           1.0     Approved   Trek Bicycles
# 3           2017-01-05           0.0     Approved  Norco Bicycles
# 4           2017-02-21           0.0     Approved           Solex
# ...                ...           ...          ...             ...
# 12965       2017-03-07           0.0     Approved   Trek Bicycles
# 12966       2017-04-02           1.0     Approved  Norco Bicycles
# 12967       2017-11-08           1.0     Approved  Giant Bicycles
# 12968       2017-09-01           1.0     Approved           Solex
# 12969       2017-09-12           0.0     Approved  Giant Bicycles
#
#       product_line product_class product_size  list_price  standard_cost  \
# 0         Standard        medium       medium      235.63         125.07
# 1         Standard        medium       medium     1577.53         826.51
# 2             Road           low        small     1720.70        1531.42
# 3         Standard        medium       medium      360.40         270.30
# 4         Standard        medium       medium       71.49          53.62
# ...            ...           ...          ...         ...            ...
# 12965     Mountain           low       medium      574.64         459.71
# 12966     Standard          high        small     1661.92        1479.11
# 12967     Standard        medium       medium     1403.50         954.82
# 12968     Standard        medium       medium      575.27         431.45
# 12969     Standard        medium        large     1765.30         709.48
#
#       new_product_first_sold_date
# 0                      2005-05-10
# 1                      2008-03-19
# 2                      2003-07-21
# 3                      2003-09-09
# 4                      2005-08-09
# ...                           ...
# 12965                  2003-02-07
# 12966                  2010-05-05
# 12967                  2016-11-14
# 12968                  1996-04-05
# 12969                  2004-07-25
#
# [12970 rows x 30 columns]

# %%
clean_custdemo.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure  age
# 0      Mass Customer                  N      Yes    11.0   64
# 1      Mass Customer                  N      Yes    16.0   37
# 2      Mass Customer                  N      Yes    15.0   63
# 8  Affluent Customer                  N      Yes     8.0   44
# 9      Mass Customer                  N      Yes    20.0   29

# %%
clean_custadd.head()
# Out:
#    customer_id              address  postcode state    country  \
# 0            1   060 Morning Avenue      2016   NSW  Australia
# 1            2  6 Meadow Vale Court      2153   NSW  Australia
# 2            4   0 Holy Cross Court      4211   QLD  Australia
# 3            5  17979 Del Mar Point      2448   NSW  Australia
# 4            6     9 Oakridge Court      3216   VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
clean_transac.head()
clean_transac.shape
# Out:
# (19445, 13)

# %%
cust_list.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            1    Laraine  Medendorp  Female
# 2            1    Laraine  Medendorp  Female
# 3            1    Laraine  Medendorp  Female
# 4            1    Laraine  Medendorp  Female
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
# 1                                   93 1953-10-12  Executive Secretary
# 2                                   93 1953-10-12  Executive Secretary
# 3                                   93 1953-10-12  Executive Secretary
# 4                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0                Health  Mass Customer                  N      Yes    11.0
# 1                Health  Mass Customer                  N      Yes    11.0
# 2                Health  Mass Customer                  N      Yes    11.0
# 3                Health  Mass Customer                  N      Yes    11.0
# 4                Health  Mass Customer                  N      Yes    11.0
#
#    age             address  postcode state    country  property_valuation  \
# 0   64  060 Morning Avenue      2016   NSW  Australia                  10
# 1   64  060 Morning Avenue      2016   NSW  Australia                  10
# 2   64  060 Morning Avenue      2016   NSW  Australia                  10
# 3   64  060 Morning Avenue      2016   NSW  Australia                  10
# 4   64  060 Morning Avenue      2016   NSW  Australia                  10
#
#    transaction_id  product_id transaction_date  online_order order_status  \
# 0              94          86       2017-12-23           0.0     Approved
# 1            3765          38       2017-04-06           1.0     Approved
# 2            5157          47       2017-05-11           1.0     Approved
# 3            9785          72       2017-01-05           0.0     Approved
# 4           13424           2       2017-02-21           0.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0      OHM Cycles     Standard        medium       medium      235.63
# 1           Solex     Standard        medium       medium     1577.53
# 2   Trek Bicycles         Road           low        small     1720.70
# 3  Norco Bicycles     Standard        medium       medium      360.40
# 4           Solex     Standard        medium       medium       71.49
#
#    standard_cost new_product_first_sold_date
# 0         125.07                  2005-05-10
# 1         826.51                  2008-03-19
# 2        1531.42                  2003-07-21
# 3         270.30                  2003-09-09
# 4          53.62                  2005-08-09

# %%
final_custdemo = cust_list
final_custdemo.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            1    Laraine  Medendorp  Female
# 2            1    Laraine  Medendorp  Female
# 3            1    Laraine  Medendorp  Female
# 4            1    Laraine  Medendorp  Female
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
# 1                                   93 1953-10-12  Executive Secretary
# 2                                   93 1953-10-12  Executive Secretary
# 3                                   93 1953-10-12  Executive Secretary
# 4                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0                Health  Mass Customer                  N      Yes    11.0
# 1                Health  Mass Customer                  N      Yes    11.0
# 2                Health  Mass Customer                  N      Yes    11.0
# 3                Health  Mass Customer                  N      Yes    11.0
# 4                Health  Mass Customer                  N      Yes    11.0
#
#    age             address  postcode state    country  property_valuation  \
# 0   64  060 Morning Avenue      2016   NSW  Australia                  10
# 1   64  060 Morning Avenue      2016   NSW  Australia                  10
# 2   64  060 Morning Avenue      2016   NSW  Australia                  10
# 3   64  060 Morning Avenue      2016   NSW  Australia                  10
# 4   64  060 Morning Avenue      2016   NSW  Australia                  10
#
#    transaction_id  product_id transaction_date  online_order order_status  \
# 0              94          86       2017-12-23           0.0     Approved
# 1            3765          38       2017-04-06           1.0     Approved
# 2            5157          47       2017-05-11           1.0     Approved
# 3            9785          72       2017-01-05           0.0     Approved
# 4           13424           2       2017-02-21           0.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0      OHM Cycles     Standard        medium       medium      235.63
# 1           Solex     Standard        medium       medium     1577.53
# 2   Trek Bicycles         Road           low        small     1720.70
# 3  Norco Bicycles     Standard        medium       medium      360.40
# 4           Solex     Standard        medium       medium       71.49
#
#    standard_cost new_product_first_sold_date
# 0         125.07                  2005-05-10
# 1         826.51                  2008-03-19
# 2        1531.42                  2003-07-21
# 3         270.30                  2003-09-09
# 4          53.62                  2005-08-09

# %%
###Get customer ID and address fields only
final_custdemo = final_custdemo.iloc[:, :13]

# %%
###Drop any duplications following join
final_custdemo = final_custdemo.drop_duplicates()
final_custdemo.head()
# Out:
#     customer_id first_name  last_name  gender  \
# 0             1    Laraine  Medendorp  Female
# 11            2        Eli    Bockman    Male
# 14            9       Mala       Lind  Female
# 20           12    Sawyere   Flattman    Male
# 27           13   Gabriele   Norcross    Male
#
#     past_3_years_bike_related_purchases        DOB  \
# 0                                    93 1953-10-12
# 11                                   81 1980-12-16
# 14                                   97 1973-03-10
# 20                                   58 1994-07-21
# 27                                   38 1955-02-15
#
#                                job_title job_industry_category  \
# 0                    Executive Secretary                Health
# 11                Administrative Officer    Financial Services
# 14  Business Systems Development Analyst           Argiculture
# 20                Nuclear Power Engineer         Manufacturing
# 27                           Developer I    Financial Services
#
#        wealth_segment deceased_indicator owns_car  tenure  age
# 0       Mass Customer                  N      Yes    11.0   64
# 11      Mass Customer                  N      Yes    16.0   37
# 14  Affluent Customer                  N      Yes     8.0   44
# 20      Mass Customer                  N       No     8.0   23
# 27     High Net Worth                  N      Yes     8.0   62

# %%
final_custdemo.shape
# Out:
# (2327, 13)

# %%
final_custadd = cust_list
final_custadd.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            1    Laraine  Medendorp  Female
# 2            1    Laraine  Medendorp  Female
# 3            1    Laraine  Medendorp  Female
# 4            1    Laraine  Medendorp  Female
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
# 1                                   93 1953-10-12  Executive Secretary
# 2                                   93 1953-10-12  Executive Secretary
# 3                                   93 1953-10-12  Executive Secretary
# 4                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0                Health  Mass Customer                  N      Yes    11.0
# 1                Health  Mass Customer                  N      Yes    11.0
# 2                Health  Mass Customer                  N      Yes    11.0
# 3                Health  Mass Customer                  N      Yes    11.0
# 4                Health  Mass Customer                  N      Yes    11.0
#
#    age             address  postcode state    country  property_valuation  \
# 0   64  060 Morning Avenue      2016   NSW  Australia                  10
# 1   64  060 Morning Avenue      2016   NSW  Australia                  10
# 2   64  060 Morning Avenue      2016   NSW  Australia                  10
# 3   64  060 Morning Avenue      2016   NSW  Australia                  10
# 4   64  060 Morning Avenue      2016   NSW  Australia                  10
#
#    transaction_id  product_id transaction_date  online_order order_status  \
# 0              94          86       2017-12-23           0.0     Approved
# 1            3765          38       2017-04-06           1.0     Approved
# 2            5157          47       2017-05-11           1.0     Approved
# 3            9785          72       2017-01-05           0.0     Approved
# 4           13424           2       2017-02-21           0.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0      OHM Cycles     Standard        medium       medium      235.63
# 1           Solex     Standard        medium       medium     1577.53
# 2   Trek Bicycles         Road           low        small     1720.70
# 3  Norco Bicycles     Standard        medium       medium      360.40
# 4           Solex     Standard        medium       medium       71.49
#
#    standard_cost new_product_first_sold_date
# 0         125.07                  2005-05-10
# 1         826.51                  2008-03-19
# 2        1531.42                  2003-07-21
# 3         270.30                  2003-09-09
# 4          53.62                  2005-08-09

# %%
###Get customer ID and address records only
final_custadd = pd.concat([final_custadd.iloc[:,0],final_custadd.iloc[:,13:18]],axis = 1)

# %%
###Drop any duplications following join
final_custadd = final_custadd.drop_duplicates()
final_custadd.head()
# Out:
#     customer_id                  address  postcode state    country  \
# 0             1       060 Morning Avenue      2016   NSW  Australia
# 11            2      6 Meadow Vale Court      2153   NSW  Australia
# 14            9          97736 7th Trail      2023   NSW  Australia
# 20           12  44339 Golden Leaf Alley      4557   QLD  Australia
# 27           13      2 Sutherland Street      3799   VIC  Australia
#
#     property_valuation
# 0                   10
# 11                  10
# 14                  12
# 20                   4
# 27                   6

# %%
final_custadd.shape
# Out:
# (2327, 6)

# %%
final_transac = cust_list
final_transac.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            1    Laraine  Medendorp  Female
# 2            1    Laraine  Medendorp  Female
# 3            1    Laraine  Medendorp  Female
# 4            1    Laraine  Medendorp  Female
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
# 1                                   93 1953-10-12  Executive Secretary
# 2                                   93 1953-10-12  Executive Secretary
# 3                                   93 1953-10-12  Executive Secretary
# 4                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0                Health  Mass Customer                  N      Yes    11.0
# 1                Health  Mass Customer                  N      Yes    11.0
# 2                Health  Mass Customer                  N      Yes    11.0
# 3                Health  Mass Customer                  N      Yes    11.0
# 4                Health  Mass Customer                  N      Yes    11.0
#
#    age             address  postcode state    country  property_valuation  \
# 0   64  060 Morning Avenue      2016   NSW  Australia                  10
# 1   64  060 Morning Avenue      2016   NSW  Australia                  10
# 2   64  060 Morning Avenue      2016   NSW  Australia                  10
# 3   64  060 Morning Avenue      2016   NSW  Australia                  10
# 4   64  060 Morning Avenue      2016   NSW  Australia                  10
#
#    transaction_id  product_id transaction_date  online_order order_status  \
# 0              94          86       2017-12-23           0.0     Approved
# 1            3765          38       2017-04-06           1.0     Approved
# 2            5157          47       2017-05-11           1.0     Approved
# 3            9785          72       2017-01-05           0.0     Approved
# 4           13424           2       2017-02-21           0.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0      OHM Cycles     Standard        medium       medium      235.63
# 1           Solex     Standard        medium       medium     1577.53
# 2   Trek Bicycles         Road           low        small     1720.70
# 3  Norco Bicycles     Standard        medium       medium      360.40
# 4           Solex     Standard        medium       medium       71.49
#
#    standard_cost new_product_first_sold_date
# 0         125.07                  2005-05-10
# 1         826.51                  2008-03-19
# 2        1531.42                  2003-07-21
# 3         270.30                  2003-09-09
# 4          53.62                  2005-08-09

# %%
###Get customer ID and transaction records only
final_transac = pd.concat([final_transac.iloc[:,0],final_transac.iloc[:,19:]],axis = 1)

# %%
final_transac.head()
# Out:
#    customer_id  product_id transaction_date  online_order order_status  \
# 0            1          86       2017-12-23           0.0     Approved
# 1            1          38       2017-04-06           1.0     Approved
# 2            1          47       2017-05-11           1.0     Approved
# 3            1          72       2017-01-05           0.0     Approved
# 4            1           2       2017-02-21           0.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0      OHM Cycles     Standard        medium       medium      235.63
# 1           Solex     Standard        medium       medium     1577.53
# 2   Trek Bicycles         Road           low        small     1720.70
# 3  Norco Bicycles     Standard        medium       medium      360.40
# 4           Solex     Standard        medium       medium       71.49
#
#    standard_cost new_product_first_sold_date
# 0         125.07                  2005-05-10
# 1         826.51                  2008-03-19
# 2        1531.42                  2003-07-21
# 3         270.30                  2003-09-09
# 4          53.62                  2005-08-09

# %%
final_transac.shape
# Out:
# (12970, 12)

# %%
writer = pd.ExcelWriter('Sprocket Central Pty Ltd Clean.xlsx', engine='xlsxwriter')

final_custdemo.to_excel(writer, sheet_name='Customer Demographic', index = False)
final_custadd.to_excel(writer, sheet_name='Customer Address', index = False)
final_transac.to_excel(writer, sheet_name='Transactions', index = False)

writer.save()
